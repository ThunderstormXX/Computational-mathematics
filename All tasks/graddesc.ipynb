# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from matplotlib import cm
from matplotlib.ticker import LinearLocator

# %matplotlib inline
plt.rc('font', **{'size' : 22})

# %%
def func(x,y):
    return 1 - np.exp(x*y)
def rotate(x,y,z,a):
    a = 2*np.pi/360 * a
    M = np.array(
        [
            [np.cos(a),-np.sin(a),0],
            [np.sin(a),np.cos(a),0],
            [0, 0   ,   1]
        ]
    )
    xyz = np.array([x,y,z])
    res = M@xyz    
    return (res[0],res[1],res[2])

# %%
x = np.arange(-1.0,1.0,0.1)
y = np.arange(-1.0,1.0,0.1)
z = func(x,y)
x,y,z = rotate(x,y,z,0)
print(x,y,z)
# Out:
# [-1.00000000e+00 -9.00000000e-01 -8.00000000e-01 -7.00000000e-01
#  -6.00000000e-01 -5.00000000e-01 -4.00000000e-01 -3.00000000e-01
#  -2.00000000e-01 -1.00000000e-01 -2.22044605e-16  1.00000000e-01
#   2.00000000e-01  3.00000000e-01  4.00000000e-01  5.00000000e-01
#   6.00000000e-01  7.00000000e-01  8.00000000e-01  9.00000000e-01] [-1.00000000e+00 -9.00000000e-01 -8.00000000e-01 -7.00000000e-01
#  -6.00000000e-01 -5.00000000e-01 -4.00000000e-01 -3.00000000e-01
#  -2.00000000e-01 -1.00000000e-01 -2.22044605e-16  1.00000000e-01
#   2.00000000e-01  3.00000000e-01  4.00000000e-01  5.00000000e-01
#   6.00000000e-01  7.00000000e-01  8.00000000e-01  9.00000000e-01] [-1.71828183 -1.24790799 -0.89648088 -0.63231622 -0.43332941 -0.28402542
#  -0.17351087 -0.09417428 -0.04081077 -0.01005017  0.         -0.01005017
#  -0.04081077 -0.09417428 -0.17351087 -0.28402542 -0.43332941 -0.63231622
#  -0.89648088 -1.24790799]

# %%
x = np.arange(-1.0,1.0,0.01)
y = np.arange(-1.0,1.0,0.01)
# x,y,z = rotate(x,y,z,0)
x,y = np.meshgrid(x,y)
z = func(x,y)

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})



surf = ax.plot_surface(x,y,z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter('{x:.02f}')

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()
